# %% [markdown]
# #RUN FROM HERE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Load the dataset (assuming the path is correctly set)
data_file_path = '/content/drive/MyDrive/GuidingRobot/LIDAR_DATA/LIDAR_DATA_UNZIPPED/lidar_like_data.csv'
df = pd.read_csv(data_file_path)

# Preprocess the DataFrame
df = df.drop(columns=['file_name'])

# %%
# Calculate mean squared distance to goal for each row
df['mean_sq_distance'] = (df['P1_goal_dist_x']**2 + df['P1_goal_dist_y']**2) / 2
num_rows_less_than_200 = df[df['mean_sq_distance'] < 100].shape[0]
print("Number of rows with mean_sq_distance less than 200:", num_rows_less_than_200)

# Initially mark all rows as part of an invalid sequence
df['valid_sequence'] = False

for i in reversed(range(len(df))):
    if df.iloc[i]['final_row_flag'] == 1:
        if df.iloc[i]['mean_sq_distance'] < 100:
            # If the sequence ending at row i is successful, mark it and any preceding rows as valid
            if last_final_flag_index == -1:
                last_final_flag_index = i  # For the first successful end sequence
            else:
                for j in range(i, last_final_flag_index + 1):
                    df.at[j, 'valid_sequence'] = True
                    print(f"Row {j} Mean Squared Distance: {df.at[j, 'mean_sq_distance']}")
            last_final_flag_index = i  # Update the last index where final_row_flag was 1
        else:
            # Reset the tracker if the end of the sequence is not successful
            last_final_flag_index = i

df_filtered = df[df['valid_sequence']]
df_filtered = df_filtered.drop(columns=['mean_sq_distance', 'valid_sequence'])


print(df_filtered.columns)
# Out:
# Number of rows with mean_sq_distance less than 200: 1598
# Row 21982 Mean Squared Distance: 74.5
# Row 21983 Mean Squared Distance: 8448.5
# Row 21984 Mean Squared Distance: 8320.0
# Row 21985 Mean Squared Distance: 8192.5
# Row 21986 Mean Squared Distance: 8066.0
# Row 21987 Mean Squared Distance: 7940.5
# Row 21988 Mean Squared Distance: 7816.0
# Row 21989 Mean Squared Distance: 7692.5
# Row 21990 Mean Squared Distance: 7570.0
# Row 21991 Mean Squared Distance: 7448.5
# Row 21992 Mean Squared Distance: 7328.0
# Row 21993 Mean Squared Distance: 7208.5
# Row 21994 Mean Squared Distance: 7090.0
# Row 21995 Mean Squared Distance: 6972.5
# Row 21996 Mean Squared Distance: 6856.0
# Row 21997 Mean Squared Distance: 6740.5
# Row 21998 Mean Squared Distance: 6626.0
# Row 21999 Mean Squared Distance: 6512.5
# Row 22000 Mean Squared Distance: 6400.0
# Row 22001 Mean Squared Distance: 6288.5
# Row 22002 Mean Squared Distance: 6178.0
# Row 22003 Mean Squared Distance: 6068.5
# Row 22004 Mean Squared Distance: 5960.0
# Row 22005 Mean Squared Distance: 5852.5
# Row 22006 Mean Squared Distance: 5746.0
# Row 22007 Mean Squared Distance: 5640.5
# Row 22008 Mean Squared Distance: 5536.0
# Row 22009 Mean Squared Distance: 5432.5
# Row 22010 Mean Squared Distance: 5330.0
# Row 22011 Mean Squared Distance: 5228.5
# Row 22012 Mean Squared Distance: 5128.0
# Row 22013 Mean Squared Distance: 5028.5
# Row 22014 Mean Squared Distance: 4930.0
# Row 22015 Mean Squared Distance: 4832.5
# Row 22016 Mean Squared Distance: 4736.0
# Row 22017 Mean Squared Distance: 4640.5
# Row 22018 Mean Squared Distance: 4546.0
# Row 22019 Mean Squared Distance: 4452.5
# Row 22020 Mean Squared Distance: 4360.0
# Row 22021 Mean Squared Distance: 4268.5
# Row 22022 Mean Squared Distance: 4178.0
# Row 22023 Mean Squared Distance: 4088.5
# Row 22024 Mean Squared Distance: 4000.0
# Row 22025 Mean Squared Distance: 3912.5
# Row 22026 Mean Squared Distance: 3826.0
# Row 22027 Mean Squared Distance: 3740.5
# Row 22028 Mean Squared Distance: 3656.0
# Row 22029 Mean Squared Distance: 3572.5
# Row 22030 Mean Squared Distance: 3490.0
# Row 22031 Mean Squared Distance: 3408.5
# Row 22032 Mean Squared Distance: 3328.0
# Row 22033 Mean Squared Distance: 3328.0
# Row 22034 Mean Squared Distance: 3328.0
# Row 22035 Mean Squared Distance: 3328.0
# Row 22036 Mean Squared Distance: 3328.0
# Row 22037 Mean Squared Distance: 3328.0
# Row 22038 Mean Squared Distance: 3328.0
# Row 22039 Mean Squared Distance: 3328.0
# Row 22040 Mean Squared Distance: 3328.0
# Row 22041 Mean Squared Distance: 3328.0
# Row 22042 Mean Squared Distance: 3328.0
# Row 22043 Mean Squared Distance: 3328.0
# Row 22044 Mean Squared Distance: 3328.0
# Row 22045 Mean Squared Distance: 3328.0
# Row 22046 Mean Squared Distance: 3328.0
# Row 22047 Mean Squared Distance: 3328.0
# Row 22048 Mean Squared Distance: 3328.0
# Row 22049 Mean Squared Distance: 3328.0
# Row 22050 Mean Squared Distance: 3248.5
# Row 22051 Mean Squared Distance: 3170.0
# Row 22052 Mean Squared Distance: 3092.5
# Row 22053 Mean Squared Distance: 3016.0
# Row 22054 Mean Squared Distance: 2940.5
# Row 22055 Mean Squared Distance: 2866.0
# Row 22056 Mean Squared Distance: 2792.5
# Row 22057 Mean Squared Distance: 2720.0
# Row 22058 Mean Squared Distance: 2648.5
# Row 22059 Mean Squared Distance: 2578.0
# Row 22060 Mean Squared Distance: 2508.5
# Row 22061 Mean Squared Distance: 2440.0
# Row 22062 Mean Squared Distance: 2372.5
# Row 22063 Mean Squared Distance: 2306.0
# Row 22064 Mean Squared Distance: 2240.5
# Row 22065 Mean Squared Distance: 2176.0
# Row 22066 Mean Squared Distance: 2112.5
# Row 22067 Mean Squared Distance: 2050.0
# Row 22068 Mean Squared Distance: 1988.5
# Row 22069 Mean Squared Distance: 1928.0
# Row 22070 Mean Squared Distance: 1868.5
# Row 22071 Mean Squared Distance: 1810.0
# Row 22072 Mean Squared Distance: 1752.5
# Row 22073 Mean Squared Distance: 1696.0
# Row 22074 Mean Squared Distance: 1640.5
# Row 22075 Mean Squared Distance: 1586.0
# Row 22076 Mean Squared Distance: 1532.5
# Row 22077 Mean Squared Distance: 1480.0
# Row 22078 Mean Squared Distance: 1428.5
# Row 22079 Mean Squared Distance: 1378.0
# Row 22080 Mean Squared Distance: 1328.5
# Row 22081 Mean Squared Distance: 1280.0
# Row 22082 Mean Squared Distance: 1232.5
# Row 22083 Mean Squared Distance: 1186.0
# Row 22084 Mean Squared Distance: 1140.5
# Row 22085 Mean Squared Distance: 1096.0
# Row 22086 Mean Squared Distance: 1052.5
# Row 22087 Mean Squared Distance: 1010.0
# Row 22088 Mean Squared Distance: 968.5
# Row 22089 Mean Squared Distance: 928.0
# Row 22090 Mean Squared Distance: 888.5
# Row 22091 Mean Squared Distance: 850.0
# Row 22092 Mean Squared Distance: 812.5
# Row 22093 Mean Squared Distance: 776.0
# Row 22094 Mean Squared Distance: 740.5
# Row 22095 Mean Squared Distance: 706.0
# Row 22096 Mean Squared Distance: 672.5
# Row 22097 Mean Squared Distance: 640.0
# Row 22098 Mean Squared Distance: 608.5
# Row 22099 Mean Squared Distance: 578.0
# Row 22100 Mean Squared Distance: 548.5
# Row 22101 Mean Squared Distance: 520.0
# Row 22102 Mean Squared Distance: 492.5
# Row 22103 Mean Squared Distance: 466.0
# Row 22104 Mean Squared Distance: 440.5
# Row 22105 Mean Squared Distance: 416.0
# Row 22106 Mean Squared Distance: 392.5
# Row 22107 Mean Squared Distance: 370.0
# Row 22108 Mean Squared Distance: 348.5
# Row 22109 Mean Squared Distance: 328.0
# Row 22110 Mean Squared Distance: 308.5
# Row 22111 Mean Squared Distance: 290.0
# Row 22112 Mean Squared Distance: 272.5
# Row 22113 Mean Squared Distance: 256.0
# Row 22114 Mean Squared Distance: 240.5
# Row 22115 Mean Squared Distance: 226.0
# Row 22116 Mean Squared Distance: 212.5
# Row 22117 Mean Squared Distance: 200.0
# Row 22118 Mean Squared Distance: 188.5
# Row 22119 Mean Squared Distance: 178.0
# Row 22120 Mean Squared Distance: 168.5
# Row 22121 Mean Squared Distance: 160.0
# Row 22122 Mean Squared Distance: 152.5
# Row 22123 Mean Squared Distance: 146.0
# Row 22124 Mean Squared Distance: 140.5
# Row 22125 Mean Squared Distance: 136.0
# Row 22126 Mean Squared Distance: 132.5
# Row 22127 Mean Squared Distance: 130.0
# Row 22128 Mean Squared Distance: 128.5
# Row 22129 Mean Squared Distance: 128.0
# Row 22130 Mean Squared Distance: 128.5
# Row 22131 Mean Squared Distance: 130.0
# Row 22132 Mean Squared Distance: 132.5
# Row 22133 Mean Squared Distance: 136.0
# Row 22134 Mean Squared Distance: 140.5
# Row 22135 Mean Squared Distance: 146.0
# Row 22136 Mean Squared Distance: 152.5
# Row 22137 Mean Squared Distance: 160.0
# Row 22138 Mean Squared Distance: 168.5
# Row 22139 Mean Squared Distance: 178.0
# Row 22140 Mean Squared Distance: 188.5
# Row 22141 Mean Squared Distance: 200.0
# Row 22142 Mean Squared Distance: 212.5
# Row 22143 Mean Squared Distance: 226.0
# Row 22144 Mean Squared Distance: 240.5
# Row 22145 Mean Squared Distance: 256.0
# Row 22146 Mean Squared Distance: 272.5
# Row 22147 Mean Squared Distance: 290.0
# Row 22148 Mean Squared Distance: 308.5
# Row 22149 Mean Squared Distance: 328.0
# Row 22150 Mean Squared Distance: 348.5
# Row 22151 Mean Squared Distance: 370.0
# Row 22152 Mean Squared Distance: 392.5
# Row 22153 Mean Squared Distance: 416.0
# Row 22154 Mean Squared Distance: 440.5
# Row 22155 Mean Squared Distance: 466.0
# Row 22156 Mean Squared Distance: 492.5
# Row 22157 Mean Squared Distance: 520.0
# Row 22158 Mean Squared Distance: 548.5
# Row 22159 Mean Squared Distance: 578.0
# Row 22160 Mean Squared Distance: 608.5
# Row 22161 Mean Squared Distance: 640.0
# Row 22162 Mean Squared Distance: 672.5
# Row 22163 Mean Squared Distance: 706.0
# Row 22164 Mean Squared Distance: 740.5
# Row 22165 Mean Squared Distance: 776.0
# Row 22166 Mean Squared Distance: 812.5
# Row 22167 Mean Squared Distance: 850.0
# Row 22168 Mean Squared Distance: 888.5
# Row 22169 Mean Squared Distance: 928.0
# Row 22170 Mean Squared Distance: 968.5
# Row 22171 Mean Squared Distance: 1010.0
# Row 22172 Mean Squared Distance: 1052.5
# Row 22173 Mean Squared Distance: 1096.0
# Row 22174 Mean Squared Distance: 1140.5
# Row 22175 Mean Squared Distance: 1186.0
# Row 22176 Mean Squared Distance: 1232.5
# Row 22177 Mean Squared Distance: 1280.0
# Row 22178 Mean Squared Distance: 1328.5
# Row 22179 Mean Squared Distance: 1378.0
# Row 10515 Mean Squared Distance: 54.5
# Row 10516 Mean Squared Distance: 66204.5
# Row 10517 Mean Squared Distance: 66258.0
# Row 10518 Mean Squared Distance: 66312.5
# Row 10519 Mean Squared Distance: 66368.0
# Row 10520 Mean Squared Distance: 66424.5
# Row 10521 Mean Squared Distance: 66482.0
# Row 10522 Mean Squared Distance: 66540.5
# Row 10523 Mean Squared Distance: 66600.0
# Row 10524 Mean Squared Distance: 66660.5
# Row 10525 Mean Squared Distance: 66722.0
# Row 10526 Mean Squared Distance: 66784.5
# Row 10527 Mean Squared Distance: 66848.0
# Row 10528 Mean Squared Distance: 66912.5
# Row 10529 Mean Squared Distance: 66978.0
# Row 10530 Mean Squared Distance: 67044.5
# Row 10531 Mean Squared Distance: 67112.0
# Row 10532 Mean Squared Distance: 67180.5
# Row 10533 Mean Squared Distance: 67250.0
# Row 10534 Mean Squared Distance: 67320.5
# Row 10535 Mean Squared Distance: 67392.0
# Row 10536 Mean Squared Distance: 67464.5
# Row 10537 Mean Squared Distance: 67538.0
# Row 10538 Mean Squared Distance: 67612.5
# Row 10539 Mean Squared Distance: 67688.0
# Row 10540 Mean Squared Distance: 67764.5
# Row 10541 Mean Squared Distance: 67842.0
# Row 10542 Mean Squared Distance: 67920.5
# Row 10543 Mean Squared Distance: 68000.0
# Row 10544 Mean Squared Distance: 68080.5
# Row 10545 Mean Squared Distance: 68162.0
# Row 10546 Mean Squared Distance: 68244.5
# Row 10547 Mean Squared Distance: 68328.0
# Row 10548 Mean Squared Distance: 68412.5
# Row 10549 Mean Squared Distance: 68498.0
# Row 10550 Mean Squared Distance: 68584.5
# Row 10551 Mean Squared Distance: 68672.0
# Row 10552 Mean Squared Distance: 68760.5
# Row 10553 Mean Squared Distance: 68850.0
# Row 10554 Mean Squared Distance: 68940.5
# Row 10555 Mean Squared Distance: 69032.0
# Row 10556 Mean Squared Distance: 69124.5
# Row 10557 Mean Squared Distance: 69218.0
# Row 10558 Mean Squared Distance: 69312.5
# Row 10559 Mean Squared Distance: 69408.0
# Row 10560 Mean Squared Distance: 69504.5
# Row 10561 Mean Squared Distance: 69602.0
# Row 10562 Mean Squared Distance: 69700.5
# Row 10563 Mean Squared Distance: 69800.0
# Row 10564 Mean Squared Distance: 69900.5
# Row 10565 Mean Squared Distance: 70002.0
# Row 10566 Mean Squared Distance: 70002.0
# Row 10567 Mean Squared Distance: 70002.0
# Row 10568 Mean Squared Distance: 70002.0
# Row 10569 Mean Squared Distance: 70002.0
# Row 10570 Mean Squared Distance: 70002.0
# Row 10571 Mean Squared Distance: 70002.0
# Row 10572 Mean Squared Distance: 70002.0
# Row 10573 Mean Squared Distance: 70002.0
# Row 10574 Mean Squared Distance: 70002.0
# Row 10575 Mean Squared Distance: 70002.0
# Row 10576 Mean Squared Distance: 70002.0
# Row 10577 Mean Squared Distance: 70002.0
# Row 10578 Mean Squared Distance: 70002.0
# Row 10579 Mean Squared Distance: 70002.0
# Row 10580 Mean Squared Distance: 70002.0
# Row 10581 Mean Squared Distance: 70002.0
# Row 10582 Mean Squared Distance: 70104.5
# Row 10583 Mean Squared Distance: 70208.0
# Row 10584 Mean Squared Distance: 70312.5
# Row 10585 Mean Squared Distance: 70418.0
# Row 10586 Mean Squared Distance: 70524.5
# Row 10587 Mean Squared Distance: 70632.0
# Row 10588 Mean Squared Distance: 70740.5
# Row 10589 Mean Squared Distance: 70850.0
# Row 10590 Mean Squared Distance: 70960.5
# Row 10591 Mean Squared Distance: 71072.0
# Row 10592 Mean Squared Distance: 71184.5
# Row 10593 Mean Squared Distance: 71298.0
# Row 10594 Mean Squared Distance: 71412.5
# Row 10595 Mean Squared Distance: 71528.0
# Row 10596 Mean Squared Distance: 71644.5
# Row 10597 Mean Squared Distance: 71762.0
# Row 10598 Mean Squared Distance: 71880.5
# Row 10599 Mean Squared Distance: 72000.0
# Row 10600 Mean Squared Distance: 72120.5
# Row 10601 Mean Squared Distance: 72242.0
# Row 10602 Mean Squared Distance: 72364.5
# Row 10603 Mean Squared Distance: 72488.0
# Row 10604 Mean Squared Distance: 72612.5
# Row 10605 Mean Squared Distance: 72738.0
# Row 10606 Mean Squared Distance: 72864.5
# Row 10607 Mean Squared Distance: 72992.0
# Row 10608 Mean Squared Distance: 73120.5
# Row 10609 Mean Squared Distance: 73250.0
# Row 10610 Mean Squared Distance: 73380.5
# Row 10611 Mean Squared Distance: 73512.0
# Row 10612 Mean Squared Distance: 73644.5
# Row 10613 Mean Squared Distance: 73778.0
# Row 10614 Mean Squared Distance: 73912.5
# Row 10615 Mean Squared Distance: 74048.0
# Row 10616 Mean Squared Distance: 74184.5
# Row 10617 Mean Squared Distance: 74322.0
# Row 10618 Mean Squared Distance: 74460.5
# Row 10619 Mean Squared Distance: 74600.0
# Row 10620 Mean Squared Distance: 74740.5
# Row 10621 Mean Squared Distance: 74882.0
# Row 10622 Mean Squared Distance: 75024.5
# Row 10623 Mean Squared Distance: 75168.0
# Row 10624 Mean Squared Distance: 75312.5
# Row 10625 Mean Squared Distance: 75458.0
# Row 10626 Mean Squared Distance: 75604.5
# Row 10627 Mean Squared Distance: 75752.0
# Row 10628 Mean Squared Distance: 75900.5
# Row 10629 Mean Squared Distance: 76050.0
# Row 10630 Mean Squared Distance: 76200.5
# Row 10631 Mean Squared Distance: 76352.0
# Row 10632 Mean Squared Distance: 76504.5
# Row 10633 Mean Squared Distance: 76658.0
# Row 10634 Mean Squared Distance: 76812.5
# Row 10635 Mean Squared Distance: 76968.0
# Row 10636 Mean Squared Distance: 77124.5
# Row 10637 Mean Squared Distance: 77282.0
# Row 10638 Mean Squared Distance: 77440.5
# Row 10639 Mean Squared Distance: 77600.0
# Row 10640 Mean Squared Distance: 77760.5
# Row 10641 Mean Squared Distance: 77922.0
# Row 10642 Mean Squared Distance: 78084.5
# Row 10643 Mean Squared Distance: 78248.0
# Row 10644 Mean Squared Distance: 78412.5
# Row 10645 Mean Squared Distance: 78578.0
# Row 10646 Mean Squared Distance: 78744.5
# Row 10647 Mean Squared Distance: 78912.0
# Row 10648 Mean Squared Distance: 79080.5
# Row 10649 Mean Squared Distance: 79250.0
# Row 10650 Mean Squared Distance: 79420.5
# Row 10651 Mean Squared Distance: 79592.0
# Row 10652 Mean Squared Distance: 79764.5
# Row 10653 Mean Squared Distance: 79938.0
# Row 10654 Mean Squared Distance: 80112.5
# Row 10655 Mean Squared Distance: 80288.0
# Row 10656 Mean Squared Distance: 80464.5
# Row 10657 Mean Squared Distance: 80642.0
# Row 10658 Mean Squared Distance: 80820.5
# Row 10659 Mean Squared Distance: 81000.0
# Row 10660 Mean Squared Distance: 81180.5
# Row 10661 Mean Squared Distance: 81362.0
# Row 10662 Mean Squared Distance: 81544.5
# Row 10663 Mean Squared Distance: 81728.0
# Row 10664 Mean Squared Distance: 81912.5
# Row 10665 Mean Squared Distance: 82098.0
# Row 10666 Mean Squared Distance: 82284.5
# Row 10667 Mean Squared Distance: 82472.0
# Row 10668 Mean Squared Distance: 82660.5
# Row 10669 Mean Squared Distance: 82850.0
# Row 10670 Mean Squared Distance: 83040.5
# Row 10671 Mean Squared Distance: 83232.0
# Row 10672 Mean Squared Distance: 83424.5
# Row 10673 Mean Squared Distance: 83618.0
# Row 10674 Mean Squared Distance: 83812.5
# Row 10675 Mean Squared Distance: 84008.0
# Row 10676 Mean Squared Distance: 84204.5
# Row 10677 Mean Squared Distance: 84402.0
# Row 10678 Mean Squared Distance: 84600.5
# Row 10679 Mean Squared Distance: 84800.0
# Row 10680 Mean Squared Distance: 85000.5
# Row 10681 Mean Squared Distance: 85202.0
# Row 10682 Mean Squared Distance: 85404.5
# Row 10683 Mean Squared Distance: 85608.0
# Row 10684 Mean Squared Distance: 85812.5
# Row 10685 Mean Squared Distance: 86018.0
# Row 10686 Mean Squared Distance: 86224.5
# Row 10687 Mean Squared Distance: 86432.0
# Row 10688 Mean Squared Distance: 86640.5
# Row 10689 Mean Squared Distance: 86850.0
# Row 10690 Mean Squared Distance: 87060.5
# Row 10691 Mean Squared Distance: 87272.0
# Row 10692 Mean Squared Distance: 87484.5
# Row 10693 Mean Squared Distance: 87698.0
# Row 10694 Mean Squared Distance: 87912.5
# Row 10695 Mean Squared Distance: 88128.0
# Row 10696 Mean Squared Distance: 88344.5
# Row 10697 Mean Squared Distance: 88562.0
# Row 10698 Mean Squared Distance: 88780.5
# Row 10699 Mean Squared Distance: 89000.0
# Row 10700 Mean Squared Distance: 89220.5
# Row 10701 Mean Squared Distance: 89442.0
# Row 10702 Mean Squared Distance: 89664.5
# Row 10703 Mean Squared Distance: 89888.0
# Row 10704 Mean Squared Distance: 89528.5
# Row 10705 Mean Squared Distance: 89170.0
# Row 10706 Mean Squared Distance: 88812.5
# Row 10707 Mean Squared Distance: 88456.0
# Row 10708 Mean Squared Distance: 88100.5
# Row 10709 Mean Squared Distance: 87746.0
# Row 10710 Mean Squared Distance: 87392.5
# Row 10711 Mean Squared Distance: 87040.0
# Row 10712 Mean Squared Distance: 86688.5
# Row 10713 Mean Squared Distance: 86338.0
# Row 10714 Mean Squared Distance: 85988.5
# Row 10715 Mean Squared Distance: 85640.0
# Row 10716 Mean Squared Distance: 85292.5
# Row 10717 Mean Squared Distance: 84946.0
# Row 10718 Mean Squared Distance: 84600.5
# Row 10719 Mean Squared Distance: 84256.0
# Row 10720 Mean Squared Distance: 83912.5
# Row 10721 Mean Squared Distance: 83570.0
# Row 10722 Mean Squared Distance: 83794.5
# Row 10723 Mean Squared Distance: 84020.0
# Row 10724 Mean Squared Distance: 84246.5
# Row 10725 Mean Squared Distance: 84474.0
# Row 10726 Mean Squared Distance: 84702.5
# Row 10727 Mean Squared Distance: 84932.0
# Row 10728 Mean Squared Distance: 85162.5
# Row 10729 Mean Squared Distance: 85162.5
# Row 10730 Mean Squared Distance: 85162.5
# Row 10731 Mean Squared Distance: 85162.5
# Row 10732 Mean Squared Distance: 85162.5
# Row 10733 Mean Squared Distance: 85162.5
# Row 10734 Mean Squared Distance: 85162.5
# Row 10735 Mean Squared Distance: 85162.5
# Row 10736 Mean Squared Distance: 85162.5
# Row 10737 Mean Squared Distance: 85162.5
# Row 10738 Mean Squared Distance: 85162.5
# Row 10739 Mean Squared Distance: 85162.5
# Row 10740 Mean Squared Distance: 85162.5
# Row 10741 Mean Squared Distance: 85162.5
# Row 10742 Mean Squared Distance: 85162.5
# Row 10743 Mean Squared Distance: 85162.5
# Row 10744 Mean Squared Distance: 85162.5
# Row 10745 Mean Squared Distance: 85162.5
# Row 10746 Mean Squared Distance: 85162.5
# Row 10747 Mean Squared Distance: 85162.5
# Row 10748 Mean Squared Distance: 85162.5
# Row 10749 Mean Squared Distance: 85162.5
# Row 10750 Mean Squared Distance: 85162.5
# Row 10751 Mean Squared Distance: 85162.5
# Row 10752 Mean Squared Distance: 85162.5
# Row 10753 Mean Squared Distance: 85162.5
# Row 10754 Mean Squared Distance: 85162.5
# Row 10755 Mean Squared Distance: 85162.5
# Row 10756 Mean Squared Distance: 85162.5
# Row 10757 Mean Squared Distance: 85162.5
# Row 10758 Mean Squared Distance: 84821.0
# Row 10759 Mean Squared Distance: 84480.5
# Row 10760 Mean Squared Distance: 84141.0
# Row 10761 Mean Squared Distance: 83802.5
# Row 10762 Mean Squared Distance: 83465.0
# Row 10763 Mean Squared Distance: 83128.5
# Row 10764 Mean Squared Distance: 82793.0
# Row 10765 Mean Squared Distance: 82458.5
# Row 10766 Mean Squared Distance: 82125.0
# Row 10767 Mean Squared Distance: 81792.5
# Row 10768 Mean Squared Distance: 81461.0
# Row 10769 Mean Squared Distance: 81130.5
# Row 10770 Mean Squared Distance: 80801.0
# Row 10771 Mean Squared Distance: 80472.5
# Row 10772 Mean Squared Distance: 80145.0
# Row 10773 Mean Squared Distance: 79818.5
# Row 10774 Mean Squared Distance: 79493.0
# Row 10775 Mean Squared Distance: 79168.5
# Row 10776 Mean Squared Distance: 78845.0
# Row 10777 Mean Squared Distance: 78522.5
# Row 10778 Mean Squared Distance: 78201.0
# Row 10779 Mean Squared Distance: 77880.5
# Row 10780 Mean Squared Distance: 77561.0
# Row 10781 Mean Squared Distance: 77242.5
# Row 10782 Mean Squared Distance: 76925.0
# Row 10783 Mean Squared Distance: 76608.5
# Row 10784 Mean Squared Distance: 76293.0
# Row 10785 Mean Squared Distance: 75978.5
# Row 10786 Mean Squared Distance: 75665.0
# Row 10787 Mean Squared Distance: 75352.5
# Row 10788 Mean Squared Distance: 75352.5
# Row 10789 Mean Squared Distance: 75352.5
# Row 10790 Mean Squared Distance: 75352.5
# Row 10791 Mean Squared Distance: 75352.5
# Row 10792 Mean Squared Distance: 75352.5
# Row 10793 Mean Squared Distance: 75352.5
# Row 10794 Mean Squared Distance: 75352.5
# Row 10795 Mean Squared Distance: 75352.5
# Row 10796 Mean Squared Distance: 75352.5
# Row 10797 Mean Squared Distance: 75352.5
# Row 10798 Mean Squared Distance: 75352.5
# Row 10799 Mean Squared Distance: 75352.5
# Row 10800 Mean Squared Distance: 75352.5
# Row 10801 Mean Squared Distance: 75352.5
# Row 10802 Mean Squared Distance: 75352.5
# Row 10803 Mean Squared Distance: 75041.0
# Row 10804 Mean Squared Distance: 74730.5
# Row 10805 Mean Squared Distance: 74421.0
# Row 10806 Mean Squared Distance: 74112.5
# Row 10807 Mean Squared Distance: 73805.0
# Row 10808 Mean Squared Distance: 73498.5
# Row 10809 Mean Squared Distance: 73193.0
# Row 10810 Mean Squared Distance: 72888.5
# Row 10811 Mean Squared Distance: 72585.0
# Row 10812 Mean Squared Distance: 72282.5
# Row 10813 Mean Squared Distance: 71981.0
# Row 10814 Mean Squared Distance: 71680.5
# Row 10815 Mean Squared Distance: 71381.0
# Row 10816 Mean Squared Distance: 71381.0
# Row 10817 Mean Squared Distance: 71381.0
# Row 10818 Mean Squared Distance: 71381.0
# Row 10819 Mean Squared Distance: 71381.0
# Row 10820 Mean Squared Distance: 71381.0
# Row 10821 Mean Squared Distance: 71381.0
# Row 10822 Mean Squared Distance: 71381.0
# Row 10823 Mean Squared Distance: 71381.0
# Row 10824 Mean Squared Distance: 71381.0
# Row 10825 Mean Squared Distance: 71381.0
# Row 10826 Mean Squared Distance: 71381.0
# Row 10827 Mean Squared Distance: 71381.0
# Row 10828 Mean Squared Distance: 71381.0
# Row 10829 Mean Squared Distance: 71381.0
# Row 10830 Mean Squared Distance: 71381.0
# Row 10831 Mean Squared Distance: 71612.5
# Row 10832 Mean Squared Distance: 71845.0
# Row 10833 Mean Squared Distance: 72078.5
# Row 10834 Mean Squared Distance: 72313.0
# Row 10835 Mean Squared Distance: 72548.5
# Row 10836 Mean Squared Distance: 72785.0
# Row 10837 Mean Squared Distance: 73022.5
# Row 10838 Mean Squared Distance: 73261.0
# Row 10839 Mean Squared Distance: 73500.5
# Row 10840 Mean Squared Distance: 73741.0
# Row 10841 Mean Squared Distance: 73982.5
# Row 10842 Mean Squared Distance: 74225.0
# Row 10843 Mean Squared Distance: 74468.5
# Row 10844 Mean Squared Distance: 74713.0
# Row 10845 Mean Squared Distance: 74958.5
# Row 10846 Mean Squared Distance: 74958.5
# Row 10847 Mean Squared Distance: 74958.5
# Row 10848 Mean Squared Distance: 74958.5
# Row 10849 Mean Squared Distance: 74958.5
# Row 10850 Mean Squared Distance: 74958.5
# Row 10851 Mean Squared Distance: 74958.5
# Row 10852 Mean Squared Distance: 74958.5
# Row 10853 Mean Squared Distance: 74958.5
# Row 10854 Mean Squared Distance: 74958.5
# Row 10855 Mean Squared Distance: 74958.5
# Row 10856 Mean Squared Distance: 74958.5
# Row 10857 Mean Squared Distance: 74958.5
# Row 10858 Mean Squared Distance: 74958.5
# Row 10859 Mean Squared Distance: 74958.5
# Row 10860 Mean Squared Distance: 74958.5
# Row 10861 Mean Squared Distance: 74958.5
# Row 10862 Mean Squared Distance: 74958.5
# Row 10863 Mean Squared Distance: 74660.0
# Row 10864 Mean Squared Distance: 74362.5
# Row 10865 Mean Squared Distance: 74066.0
# Row 10866 Mean Squared Distance: 73770.5
# Row 10867 Mean Squared Distance: 73476.0
# Row 10868 Mean Squared Distance: 73182.5
# Row 10869 Mean Squared Distance: 72890.0
# Row 10870 Mean Squared Distance: 72890.0
# Row 10871 Mean Squared Distance: 72890.0
# Row 10872 Mean Squared Distance: 72890.0
# Row 10873 Mean Squared Distance: 72890.0
# Row 10874 Mean Squared Distance: 72890.0
# Row 10875 Mean Squared Distance: 73136.5
# Row 10876 Mean Squared Distance: 73384.0
# Row 10877 Mean Squared Distance: 73632.5
# Row 10878 Mean Squared Distance: 73882.0
# Row 10879 Mean Squared Distance: 74132.5
# Row 10880 Mean Squared Distance: 74384.0
# Row 10881 Mean Squared Distance: 74636.5
# Row 10882 Mean Squared Distance: 74890.0
# Row 10883 Mean Squared Distance: 74598.5
# Row 10884 Mean Squared Distance: 74308.0
# Row 10885 Mean Squared Distance: 74018.5
# Row 10886 Mean Squared Distance: 73730.0
# Row 10887 Mean Squared Distance: 73442.5
# Row 10888 Mean Squared Distance: 73442.5
# Row 10889 Mean Squared Distance: 73442.5
# Row 10890 Mean Squared Distance: 73442.5
# Row 10891 Mean Squared Distance: 73442.5
# Row 10892 Mean Squared Distance: 73442.5
# Row 10893 Mean Squared Distance: 73442.5
# Row 10894 Mean Squared Distance: 73442.5
# Row 10895 Mean Squared Distance: 73442.5
# Row 10896 Mean Squared Distance: 73442.5
# Row 10897 Mean Squared Distance: 73442.5
# Row 10898 Mean Squared Distance: 73442.5
# Row 10899 Mean Squared Distance: 73442.5
# Row 10900 Mean Squared Distance: 73442.5
# Row 10901 Mean Squared Distance: 73442.5
# Row 10902 Mean Squared Distance: 73442.5
# Row 10903 Mean Squared Distance: 73442.5
# Row 10904 Mean Squared Distance: 73442.5
# Row 10905 Mean Squared Distance: 73442.5
# Row 10906 Mean Squared Distance: 73442.5
# Row 10907 Mean Squared Distance: 73442.5
# Row 10908 Mean Squared Distance: 73442.5
# Row 10909 Mean Squared Distance: 73156.0
# Row 10910 Mean Squared Distance: 72870.5
# Row 10911 Mean Squared Distance: 72586.0
# Row 10912 Mean Squared Distance: 72302.5
# Row 10913 Mean Squared Distance: 72020.0
# Row 10914 Mean Squared Distance: 72020.0
# Row 10915 Mean Squared Distance: 72020.0
# Row 10916 Mean Squared Distance: 72020.0
# Row 10917 Mean Squared Distance: 72020.0
# Row 10918 Mean Squared Distance: 72020.0
# Row 10919 Mean Squared Distance: 72020.0
# Row 10920 Mean Squared Distance: 72020.0
# Row 10921 Mean Squared Distance: 72020.0
# Row 10922 Mean Squared Distance: 72020.0
# Row 10923 Mean Squared Distance: 72020.0
# Row 10924 Mean Squared Distance: 72020.0
# Row 10925 Mean Squared Distance: 72020.0
# Row 10926 Mean Squared Distance: 72020.0
# Row 10927 Mean Squared Distance: 72020.0
# Row 10928 Mean Squared Distance: 72020.0
# Row 10929 Mean Squared Distance: 72020.0
# Row 10930 Mean Squared Distance: 72020.0
# Row 10931 Mean Squared Distance: 72020.0
# Row 10932 Mean Squared Distance: 72020.0
# Row 10933 Mean Squared Distance: 71766.5
# Row 10934 Mean Squared Distance: 71485.0
# Row 10935 Mean Squared Distance: 71204.5
# Row 10936 Mean Squared Distance: 70925.0
# Row 10937 Mean Squared Distance: 70646.5
# Row 10938 Mean Squared Distance: 70369.0
# Row 10939 Mean Squared Distance: 70092.5
# Row 10940 Mean Squared Distance: 69817.0
# Row 10941 Mean Squared Distance: 69542.5
# Row 10942 Mean Squared Distance: 69269.0
# Row 10943 Mean Squared Distance: 68996.5
# Row 10944 Mean Squared Distance: 68725.0
# Row 10945 Mean Squared Distance: 68454.5
# Row 10946 Mean Squared Distance: 68185.0
# Row 10947 Mean Squared Distance: 67916.5
# Row 10948 Mean Squared Distance: 67649.0
# Row 10949 Mean Squared Distance: 67382.5
# Row 10950 Mean Squared Distance: 67117.0
# Row 10951 Mean Squared Distance: 67117.0
# Row 10952 Mean Squared Distance: 67117.0
# Row 10953 Mean Squared Distance: 67117.0
# Row 10954 Mean Squared Distance: 67117.0
# Row 10955 Mean Squared Distance: 66864.5
# Row 10956 Mean Squared Distance: 66613.0
# Row 10957 Mean Squared Distance: 66362.5
# Row 10958 Mean Squared Distance: 66113.0
# Row 10959 Mean Squared Distance: 65864.5
# Row 10960 Mean Squared Distance: 65617.0
# Row 10961 Mean Squared Distance: 65370.5
# Row 10962 Mean Squared Distance: 65125.0
# Row 10963 Mean Squared Distance: 64880.5
# Row 10964 Mean Squared Distance: 64637.0
# Row 10965 Mean Squared Distance: 64637.0
# Row 10966 Mean Squared Distance: 64372.5
# Row 10967 Mean Squared Distance: 64109.0
# Row 10968 Mean Squared Distance: 63846.5
# Row 10969 Mean Squared Distance: 63585.0
# Row 10970 Mean Squared Distance: 63324.5
# Row 10971 Mean Squared Distance: 63065.0
# Row 10972 Mean Squared Distance: 62806.5
# Row 10973 Mean Squared Distance: 62549.0
# Row 10974 Mean Squared Distance: 62292.5
# Row 10975 Mean Squared Distance: 62037.0
# Row 10976 Mean Squared Distance: 61782.5
# Row 10977 Mean Squared Distance: 61529.0
# Row 10978 Mean Squared Distance: 61276.5
# Row 10979 Mean Squared Distance: 61276.5
# Row 10980 Mean Squared Distance: 61276.5
# Row 10981 Mean Squared Distance: 61276.5
# Row 10982 Mean Squared Distance: 61276.5
# Row 10983 Mean Squared Distance: 61276.5
# Row 10984 Mean Squared Distance: 61034.0
# Row 10985 Mean Squared Distance: 60792.5
# Row 10986 Mean Squared Distance: 60552.0
# Row 10987 Mean Squared Distance: 60312.5
# Row 10988 Mean Squared Distance: 60074.0
# Row 10989 Mean Squared Distance: 59836.5
# Row 10990 Mean Squared Distance: 59585.0
# Row 10991 Mean Squared Distance: 59334.5
# Row 10992 Mean Squared Distance: 59334.5
# Row 10993 Mean Squared Distance: 59098.0
# Row 10994 Mean Squared Distance: 59098.0
# Row 10995 Mean Squared Distance: 59098.0
# Row 10996 Mean Squared Distance: 59098.0
# Row 10997 Mean Squared Distance: 59098.0
# Row 10998 Mean Squared Distance: 59098.0
# Row 10999 Mean Squared Distance: 59098.0
# Row 11000 Mean Squared Distance: 59098.0
# Row 11001 Mean Squared Distance: 59098.0
# Row 11002 Mean Squared Distance: 59098.0
# Row 11003 Mean Squared Distance: 59098.0
# Row 11004 Mean Squared Distance: 59098.0
# Row 11005 Mean Squared Distance: 59098.0
# Row 11006 Mean Squared Distance: 59098.0
# Row 11007 Mean Squared Distance: 58848.5
# Row 11008 Mean Squared Distance: 58600.0
# Row 11009 Mean Squared Distance: 58352.5
# Row 11010 Mean Squared Distance: 58106.0
# Row 11011 Mean Squared Distance: 57860.5
# Row 11012 Mean Squared Distance: 57616.0
# Row 11013 Mean Squared Distance: 57372.5
# Row 11014 Mean Squared Distance: 57130.0
# Row 11015 Mean Squared Distance: 56888.5
# Row 11016 Mean Squared Distance: 56648.0
# Row 11017 Mean Squared Distance: 56408.5
# Row 11018 Mean Squared Distance: 56170.0
# Row 11019 Mean Squared Distance: 55932.5
# Row 11020 Mean Squared Distance: 55696.0
# Row 11021 Mean Squared Distance: 55460.5
# Row 11022 Mean Squared Distance: 55226.0
# Row 11023 Mean Squared Distance: 54992.5
# Row 11024 Mean Squared Distance: 54760.0
# Row 11025 Mean Squared Distance: 54528.5
# Row 11026 Mean Squared Distance: 54298.0
# Row 11027 Mean Squared Distance: 54068.5
# Row 11028 Mean Squared Distance: 53840.0
# Row 11029 Mean Squared Distance: 53612.5
# Row 11030 Mean Squared Distance: 53386.0
# Row 11031 Mean Squared Distance: 53160.5
# Row 11032 Mean Squared Distance: 52936.0
# Row 11033 Mean Squared Distance: 52712.5
# Row 11034 Mean Squared Distance: 52490.0
# Row 11035 Mean Squared Distance: 52268.5
# Row 11036 Mean Squared Distance: 52048.0
# Row 11037 Mean Squared Distance: 51828.5
# Row 11038 Mean Squared Distance: 51828.5
# Row 11039 Mean Squared Distance: 51828.5
# Row 11040 Mean Squared Distance: 51828.5
# Row 11041 Mean Squared Distance: 51828.5
# Row 11042 Mean Squared Distance: 51828.5
# Row 11043 Mean Squared Distance: 51828.5
# Row 11044 Mean Squared Distance: 51828.5
# Row 11045 Mean Squared Distance: 51828.5
# Row 11046 Mean Squared Distance: 51828.5
# Row 11047 Mean Squared Distance: 51610.0
# Row 11048 Mean Squared Distance: 51392.5
# Row 11049 Mean Squared Distance: 51176.0
# Row 11050 Mean Squared Distance: 50960.5
# Row 11051 Mean Squared Distance: 50746.0
# Row 11052 Mean Squared Distance: 50510.5
# Row 11053 Mean Squared Distance: 50276.0
# Row 11054 Mean Squared Distance: 50062.5
# Row 11055 Mean Squared Distance: 49850.0
# Row 11056 Mean Squared Distance: 49638.5
# Row 11057 Mean Squared Distance: 49428.0
# Row 11058 Mean Squared Distance: 49218.5
# Row 11059 Mean Squared Distance: 49010.0
# Row 11060 Mean Squared Distance: 48802.5
# Row 11061 Mean Squared Distance: 48596.0
# Row 11062 Mean Squared Distance: 48390.5
# Row 11063 Mean Squared Distance: 48186.0
# Row 11064 Mean Squared Distance: 47982.5
# Row 11065 Mean Squared Distance: 47982.5
# Row 11066 Mean Squared Distance: 47982.5
# Row 11067 Mean Squared Distance: 47982.5
# Row 11068 Mean Squared Distance: 47982.5
# Row 11069 Mean Squared Distance: 47982.5
# Row 11070 Mean Squared Distance: 47982.5
# Row 11071 Mean Squared Distance: 47982.5
# Row 11072 Mean Squared Distance: 47982.5
# Row 11073 Mean Squared Distance: 47982.5
# Row 11074 Mean Squared Distance: 47982.5
# Row 11075 Mean Squared Distance: 47982.5
# Row 11076 Mean Squared Distance: 47780.0
# Row 11077 Mean Squared Distance: 47578.5
# Row 11078 Mean Squared Distance: 47378.0
# Row 11079 Mean Squared Distance: 47178.5
# Row 11080 Mean Squared Distance: 46980.0
# Row 11081 Mean Squared Distance: 46782.5
# Row 11082 Mean Squared Distance: 46586.0
# Row 11083 Mean Squared Distance: 46390.5
# Row 11084 Mean Squared Distance: 46196.0
# Row 11085 Mean Squared Distance: 46002.5
# Row 11086 Mean Squared Distance: 45810.0
# Row 11087 Mean Squared Distance: 45618.5
# Row 11088 Mean Squared Distance: 45428.0
# Row 11089 Mean Squared Distance: 45238.5
# Row 11090 Mean Squared Distance: 45050.0
# Row 11091 Mean Squared Distance: 44862.5
# Row 11092 Mean Squared Distance: 44676.0
# Row 11093 Mean Squared Distance: 44490.5
# Row 11094 Mean Squared Distance: 44306.0
# Row 11095 Mean Squared Distance: 44122.5
# Row 11096 Mean Squared Distance: 43940.0
# Row 11097 Mean Squared Distance: 43758.5
# Row 11098 Mean Squared Distance: 43578.0
# Row 11099 Mean Squared Distance: 43398.5
# Row 11100 Mean Squared Distance: 43220.0
# Row 11101 Mean Squared Distance: 43042.5
# Row 11102 Mean Squared Distance: 42866.0
# Row 11103 Mean Squared Distance: 42690.5
# Row 11104 Mean Squared Distance: 42516.0
# Row 11105 Mean Squared Distance: 42342.5
# Row 11106 Mean Squared Distance: 42170.0
# Row 11107 Mean Squared Distance: 41998.5
# Row 11108 Mean Squared Distance: 41828.0
# Row 11109 Mean Squared Distance: 41658.5
# Row 11110 Mean Squared Distance: 41490.0
# Row 11111 Mean Squared Distance: 41322.5
# Row 11112 Mean Squared Distance: 41156.0
# Row 11113 Mean Squared Distance: 40990.5
# Row 11114 Mean Squared Distance: 40826.0
# Row 11115 Mean Squared Distance: 40662.5
# Row 11116 Mean Squared Distance: 40500.0
# Row 11117 Mean Squared Distance: 40338.5
# Row 11118 Mean Squared Distance: 40178.0
# Row 11119 Mean Squared Distance: 40018.5
# Row 11120 Mean Squared Distance: 39860.0
# Row 11121 Mean Squared Distance: 39702.5
# Row 11122 Mean Squared Distance: 39546.0
# Row 11123 Mean Squared Distance: 39390.5
# Row 11124 Mean Squared Distance: 39236.0
# Row 11125 Mean Squared Distance: 39082.5
# Row 11126 Mean Squared Distance: 38930.0
# Row 11127 Mean Squared Distance: 38778.5
# Row 11128 Mean Squared Distance: 38628.0
# Row 11129 Mean Squared Distance: 38478.5
# Row 11130 Mean Squared Distance: 38330.0
# Row 11131 Mean Squared Distance: 38182.5
# Row 11132 Mean Squared Distance: 38036.0
# Row 11133 Mean Squared Distance: 37890.5
# Row 11134 Mean Squared Distance: 37746.0
# Row 11135 Mean Squared Distance: 37602.5
# Row 11136 Mean Squared Distance: 37460.0
# Row 11137 Mean Squared Distance: 37318.5
# Row 11138 Mean Squared Distance: 37178.0
# Row 11139 Mean Squared Distance: 37038.5
# Row 11140 Mean Squared Distance: 36900.0
# Row 11141 Mean Squared Distance: 36762.5
# Row 11142 Mean Squared Distance: 36626.0
# Row 11143 Mean Squared Distance: 36490.5
# Row 11144 Mean Squared Distance: 36356.0
# Row 11145 Mean Squared Distance: 36222.5
# Row 11146 Mean Squared Distance: 36090.0
# Row 11147 Mean Squared Distance: 35958.5
# Row 11148 Mean Squared Distance: 35828.0
# Row 11149 Mean Squared Distance: 35698.5
# Row 11150 Mean Squared Distance: 35570.0
# Row 11151 Mean Squared Distance: 35442.5
# Row 11152 Mean Squared Distance: 35316.0
# Row 11153 Mean Squared Distance: 35190.5
# Row 11154 Mean Squared Distance: 35066.0
# Row 11155 Mean Squared Distance: 34942.5
# Row 11156 Mean Squared Distance: 34820.0
# Row 11157 Mean Squared Distance: 34698.5
# Row 11158 Mean Squared Distance: 34578.0
# Row 11159 Mean Squared Distance: 34458.5
# Row 11160 Mean Squared Distance: 34340.0
# Row 11161 Mean Squared Distance: 34222.5
# Row 11162 Mean Squared Distance: 34106.0
# Row 11163 Mean Squared Distance: 33990.5
# Row 11164 Mean Squared Distance: 33876.0
# Row 11165 Mean Squared Distance: 33762.5
# Row 11166 Mean Squared Distance: 33650.0
# Row 11167 Mean Squared Distance: 33538.5
# Row 11168 Mean Squared Distance: 33428.0
# Row 11169 Mean Squared Distance: 33318.5
# Row 11170 Mean Squared Distance: 33210.0
# Row 11171 Mean Squared Distance: 33102.5
# Row 11172 Mean Squared Distance: 32996.0
# Row 11173 Mean Squared Distance: 32890.5
# Row 11174 Mean Squared Distance: 32786.0
# Row 11175 Mean Squared Distance: 32682.5
# Row 11176 Mean Squared Distance: 32580.0
# Row 11177 Mean Squared Distance: 32478.5
# Row 11178 Mean Squared Distance: 32378.0
# Row 11179 Mean Squared Distance: 32278.5
# Row 11180 Mean Squared Distance: 32180.0
# Row 11181 Mean Squared Distance: 32082.5
# Row 11182 Mean Squared Distance: 31986.0
# Row 11183 Mean Squared Distance: 31890.5
# Row 11184 Mean Squared Distance: 31796.0
# Row 11185 Mean Squared Distance: 31702.5
# Row 11186 Mean Squared Distance: 31610.0
# Row 11187 Mean Squared Distance: 31518.5
# Row 11188 Mean Squared Distance: 31428.0
# Row 11189 Mean Squared Distance: 31338.5
# Row 11190 Mean Squared Distance: 31250.0
# Row 11191 Mean Squared Distance: 31162.5
# Row 11192 Mean Squared Distance: 31076.0
# Row 11193 Mean Squared Distance: 30990.5
# Row 11194 Mean Squared Distance: 30906.0
# Row 11195 Mean Squared Distance: 30822.5
# Row 11196 Mean Squared Distance: 30740.0
# Row 11197 Mean Squared Distance: 30658.5
# Row 11198 Mean Squared Distance: 30578.0
# Row 11199 Mean Squared Distance: 30498.5
# Row 11200 Mean Squared Distance: 30420.0
# Row 11201 Mean Squared Distance: 30342.5
# Row 11202 Mean Squared Distance: 30266.0
# Row 11203 Mean Squared Distance: 30190.5
# Row 11204 Mean Squared Distance: 30116.0
# Row 11205 Mean Squared Distance: 30042.5
# Row 11206 Mean Squared Distance: 29970.0
# Row 11207 Mean Squared Distance: 29898.5
# Row 11208 Mean Squared Distance: 29828.0
# Row 11209 Mean Squared Distance: 29758.5
# Row 11210 Mean Squared Distance: 29690.0
# Row 11211 Mean Squared Distance: 29622.5
# Row 11212 Mean Squared Distance: 29622.5
# Row 11213 Mean Squared Distance: 29622.5
# Row 11214 Mean Squared Distance: 29622.5
# Row 11215 Mean Squared Distance: 29389.0
# Row 11216 Mean Squared Distance: 29156.5
# Row 11217 Mean Squared Distance: 28925.0
# Row 11218 Mean Squared Distance: 28694.5
# Row 11219 Mean Squared Distance: 28465.0
# Row 11220 Mean Squared Distance: 28236.5
# Row 11221 Mean Squared Distance: 28009.0
# Row 11222 Mean Squared Distance: 27782.5
# Row 11223 Mean Squared Distance: 27557.0
# Row 11224 Mean Squared Distance: 27332.5
# Row 11225 Mean Squared Distance: 27109.0
# Row 11226 Mean Squared Distance: 26886.5
# Row 11227 Mean Squared Distance: 26665.0
# Row 11228 Mean Squared Distance: 26444.5
# Row 11229 Mean Squared Distance: 26225.0
# Row 11230 Mean Squared Distance: 26006.5
# Row 11231 Mean Squared Distance: 25789.0
# Row 11232 Mean Squared Distance: 25722.5
# Row 11233 Mean Squared Distance: 25657.0
# Row 11234 Mean Squared Distance: 25592.5
# Row 11235 Mean Squared Distance: 25529.0
# Row 11236 Mean Squared Distance: 25466.5
# Row 11237 Mean Squared Distance: 25405.0
# Row 11238 Mean Squared Distance: 25344.5
# Row 11239 Mean Squared Distance: 25285.0
# Row 11240 Mean Squared Distance: 25226.5
# Row 11241 Mean Squared Distance: 25226.5
# Row 11242 Mean Squared Distance: 25226.5
# Row 11243 Mean Squared Distance: 25226.5
# Row 11244 Mean Squared Distance: 25226.5
# Row 11245 Mean Squared Distance: 25226.5
# Row 11246 Mean Squared Distance: 25226.5
# Row 11247 Mean Squared Distance: 25226.5
# Row 11248 Mean Squared Distance: 25226.5
# Row 11249 Mean Squared Distance: 25226.5
# Row 11250 Mean Squared Distance: 25226.5
# Row 11251 Mean Squared Distance: 25226.5
# Row 11252 Mean Squared Distance: 25226.5
# Row 11253 Mean Squared Distance: 25226.5
# Row 11254 Mean Squared Distance: 25226.5
# Row 11255 Mean Squared Distance: 25226.5
# Row 11256 Mean Squared Distance: 25226.5
# Row 11257 Mean Squared Distance: 25226.5
# Row 11258 Mean Squared Distance: 25226.5
# Row 11259 Mean Squared Distance: 25226.5
# Row 11260 Mean Squared Distance: 25226.5
# Row 11261 Mean Squared Distance: 25226.5
# Row 11262 Mean Squared Distance: 25226.5
# Row 11263 Mean Squared Distance: 25226.5
# Row 11264 Mean Squared Distance: 25226.5
# Row 11265 Mean Squared Distance: 25226.5
# Row 11266 Mean Squared Distance: 25226.5
# Row 11267 Mean Squared Distance: 25226.5
# Row 11268 Mean Squared Distance: 25226.5
# Row 11269 Mean Squared Distance: 25169.0
# Row 11270 Mean Squared Distance: 25112.5
# Row 11271 Mean Squared Distance: 25057.0
# Row 11272 Mean Squared Distance: 25002.5
# Row 11273 Mean Squared Distance: 24949.0
# Row 11274 Mean Squared Distance: 24896.5
# Row 11275 Mean Squared Distance: 24845.0
# Row 11276 Mean Squared Distance: 24794.5
# Row 11277 Mean Squared Distance: 24745.0
# Row 11278 Mean Squared Distance: 24696.5
# Row 11279 Mean Squared Distance: 24649.0
# Row 11280 Mean Squared Distance: 24602.5
# Row 11281 Mean Squared Distance: 24557.0
# Row 11282 Mean Squared Distance: 24512.5
# Row 11283 Mean Squared Distance: 24469.0
# Row 11284 Mean Squared Distance: 24426.5
# Row 11285 Mean Squared Distance: 24385.0
# Row 11286 Mean Squared Distance: 24344.5
# Row 11287 Mean Squared Distance: 24305.0
# Row 11288 Mean Squared Distance: 24266.5
# Row 11289 Mean Squared Distance: 24229.0
# Row 11290 Mean Squared Distance: 24192.5
# Row 11291 Mean Squared Distance: 24157.0
# Row 11292 Mean Squared Distance: 24122.5
# Row 11293 Mean Squared Distance: 24089.0
# Row 11294 Mean Squared Distance: 24056.5
# Row 11295 Mean Squared Distance: 24025.0
# Row 11296 Mean Squared Distance: 24025.0
# Row 11297 Mean Squared Distance: 24025.0
# Row 11298 Mean Squared Distance: 24025.0
# Row 11299 Mean Squared Distance: 24025.0
# Row 11300 Mean Squared Distance: 24025.0
# Row 11301 Mean Squared Distance: 23808.5
# Row 11302 Mean Squared Distance: 23593.0
# Row 11303 Mean Squared Distance: 23378.5
# Row 11304 Mean Squared Distance: 23165.0
# Row 11305 Mean Squared Distance: 22952.5
# Row 11306 Mean Squared Distance: 22741.0
# Row 11307 Mean Squared Distance: 22530.5
# Row 11308 Mean Squared Distance: 22321.0
# Row 11309 Mean Squared Distance: 22112.5
# Row 11310 Mean Squared Distance: 22112.5
# Row 11311 Mean Squared Distance: 22112.5
# Row 11312 Mean Squared Distance: 22112.5
# Row 11313 Mean Squared Distance: 22112.5
# Row 11314 Mean Squared Distance: 22112.5
# Row 11315 Mean Squared Distance: 22082.0
# Row 11316 Mean Squared Distance: 22052.5
# Row 11317 Mean Squared Distance: 22024.0
# Row 11318 Mean Squared Distance: 21996.5
# Row 11319 Mean Squared Distance: 21970.0
# Row 11320 Mean Squared Distance: 21944.5
# Row 11321 Mean Squared Distance: 21920.0
# Row 11322 Mean Squared Distance: 21896.5
# Row 11323 Mean Squared Distance: 21874.0
# Row 11324 Mean Squared Distance: 21852.5
# Row 11325 Mean Squared Distance: 21832.0
# Row 11326 Mean Squared Distance: 21812.5
# Row 11327 Mean Squared Distance: 21794.0
# Row 11328 Mean Squared Distance: 21586.5
# Row 11329 Mean Squared Distance: 21586.5
# Row 11330 Mean Squared Distance: 21586.5
# Row 11331 Mean Squared Distance: 21586.5
# Row 11332 Mean Squared Distance: 21586.5
# Row 11333 Mean Squared Distance: 21586.5
# Row 11334 Mean Squared Distance: 21586.5
# Row 11335 Mean Squared Distance: 21586.5
# Row 11336 Mean Squared Distance: 21586.5
# Row 11337 Mean Squared Distance: 21586.5
# Row 11338 Mean Squared Distance: 21586.5
# Row 11339 Mean Squared Distance: 21586.5
# Row 11340 Mean Squared Distance: 21586.5
# Row 11341 Mean Squared Distance: 21586.5
# Row 11342 Mean Squared Distance: 21586.5
# Row 11343 Mean Squared Distance: 21586.5
# Row 11344 Mean Squared Distance: 21586.5
# Row 11345 Mean Squared Distance: 21586.5
# Row 11346 Mean Squared Distance: 21586.5
# Row 11347 Mean Squared Distance: 21586.5
# Row 11348 Mean Squared Distance: 21586.5
# Row 11349 Mean Squared Distance: 21586.5
# Row 11350 Mean Squared Distance: 21586.5
# Row 11351 Mean Squared Distance: 21586.5
# Row 11352 Mean Squared Distance: 21586.5
# Row 11353 Mean Squared Distance: 21586.5
# Row 11354 Mean Squared Distance: 21586.5
# Row 11355 Mean Squared Distance: 21586.5
# Row 11356 Mean Squared Distance: 21586.5
# Row 11357 Mean Squared Distance: 21586.5
# Row 11358 Mean Squared Distance: 21586.5
# Row 11359 Mean Squared Distance: 21586.5
# Row 11360 Mean Squared Distance: 21586.5
# Row 11361 Mean Squared Distance: 21586.5
# Row 11362 Mean Squared Distance: 21586.5
# Row 11363 Mean Squared Distance: 21586.5
# Row 11364 Mean Squared Distance: 21380.0
# Row 11365 Mean Squared Distance: 21174.5
# Row 11366 Mean Squared Distance: 20970.0
# Row 11367 Mean Squared Distance: 20766.5
# Row 11368 Mean Squared Distance: 20564.0
# Row 11369 Mean Squared Distance: 20362.5
# Row 11370 Mean Squared Distance: 20162.0
# Row 11371 Mean Squared Distance: 19962.5
# Row 11372 Mean Squared Distance: 19764.0
# Row 11373 Mean Squared Distance: 19566.5
# Row 11374 Mean Squared Distance: 19370.0
# Row 11375 Mean Squared Distance: 19174.5
# Row 11376 Mean Squared Distance: 18980.0
# Row 11377 Mean Squared Distance: 18980.0
# Row 11378 Mean Squared Distance: 18980.0
# Row 11379 Mean Squared Distance: 18980.0
# Row 11380 Mean Squared Distance: 18980.0
# Row 11381 Mean Squared Distance: 18962.5
# Row 11382 Mean Squared Distance: 18946.0
# Row 11383 Mean Squared Distance: 18930.5
# Row 11384 Mean Squared Distance: 18916.0
# Row 11385 Mean Squared Distance: 18902.5
# Row 11386 Mean Squared Distance: 18890.0
# Row 11387 Mean Squared Distance: 18878.5
# Row 11388 Mean Squared Distance: 18868.0
# Row 11389 Mean Squared Distance: 18858.5
# Row 11390 Mean Squared Distance: 18858.5
# Row 11391 Mean Squared Distance: 18858.5
# Row 11392 Mean Squared Distance: 18858.5
# Row 11393 Mean Squared Distance: 18858.5
# Row 11394 Mean Squared Distance: 18858.5
# Row 11395 Mean Squared Distance: 18858.5
# Row 11396 Mean Squared Distance: 18858.5
# Row 11397 Mean Squared Distance: 18858.5
# Row 11398 Mean Squared Distance: 18858.5
# Row 11399 Mean Squared Distance: 18858.5
# Row 11400 Mean Squared Distance: 18858.5
# Row 11401 Mean Squared Distance: 18858.5
# Row 11402 Mean Squared Distance: 18858.5
# Row 11403 Mean Squared Distance: 18858.5
# Row 11404 Mean Squared Distance: 18858.5
# Row 11405 Mean Squared Distance: 18858.5
# Row 11406 Mean Squared Distance: 18858.5
# Row 11407 Mean Squared Distance: 18858.5
# Row 11408 Mean Squared Distance: 18858.5
# Row 11409 Mean Squared Distance: 18858.5
# Row 11410 Mean Squared Distance: 18858.5
# Row 11411 Mean Squared Distance: 18665.0
# Row 11412 Mean Squared Distance: 18472.5
# Row 11413 Mean Squared Distance: 18281.0
# Row 11414 Mean Squared Distance: 18090.5
# Row 11415 Mean Squared Distance: 17901.0
# Row 11416 Mean Squared Distance: 17712.5
# Row 11417 Mean Squared Distance: 17525.0
# Row 11418 Mean Squared Distance: 17338.5
# Row 11419 Mean Squared Distance: 17153.0
# Row 11420 Mean Squared Distance: 16968.5
# Row 11421 Mean Squared Distance: 16785.0
# Row 11422 Mean Squared Distance: 16602.5
# Row 11423 Mean Squared Distance: 16421.0
# Row 11424 Mean Squared Distance: 16421.0
# Row 11425 Mean Squared Distance: 16421.0
# Row 11426 Mean Squared Distance: 16421.0
# Row 11427 Mean Squared Distance: 16240.5
# Row 11428 Mean Squared Distance: 16240.5
# Row 11429 Mean Squared Distance: 16240.5
# Row 11430 Mean Squared Distance: 16240.5
# Row 11431 Mean Squared Distance: 16240.5
# Row 11432 Mean Squared Distance: 16240.5
# Row 11433 Mean Squared Distance: 16240.5
# Row 11434 Mean Squared Distance: 16240.5
# Row 11435 Mean Squared Distance: 16240.5
# Row 11436 Mean Squared Distance: 16232.0
# Row 11437 Mean Squared Distance: 16224.5
# Row 11438 Mean Squared Distance: 16218.0
# Row 11439 Mean Squared Distance: 16212.5
# Row 11440 Mean Squared Distance: 16208.0
# Row 11441 Mean Squared Distance: 16204.5
# Row 11442 Mean Squared Distance: 16202.0
# Row 11443 Mean Squared Distance: 16200.5
# Row 11444 Mean Squared Distance: 16200.5
# Row 11445 Mean Squared Distance: 16200.5
# Row 11446 Mean Squared Distance: 16200.5
# Row 11447 Mean Squared Distance: 16200.5
# Row 11448 Mean Squared Distance: 16200.5
# Row 11449 Mean Squared Distance: 16200.5
# Row 11450 Mean Squared Distance: 16200.5
# Row 11451 Mean Squared Distance: 16200.5
# Row 11452 Mean Squared Distance: 16200.5
# Row 11453 Mean Squared Distance: 16200.5
# Row 11454 Mean Squared Distance: 16200.0
# Row 11455 Mean Squared Distance: 16200.5
# Row 11456 Mean Squared Distance: 16202.0
# Row 11457 Mean Squared Distance: 16204.5
# Row 11458 Mean Squared Distance: 16208.0
# Row 11459 Mean Squared Distance: 16028.5
# Row 11460 Mean Squared Distance: 15850.0
# Row 11461 Mean Squared Distance: 15854.5
# Row 11462 Mean Squared Distance: 15860.0
# Row 11463 Mean Squared Distance: 15866.5
# Row 11464 Mean Squared Distance: 15874.0
# Row 11465 Mean Squared Distance: 15874.0
# Row 11466 Mean Squared Distance: 15882.5
# Row 11467 Mean Squared Distance: 15882.5
# Row 11468 Mean Squared Distance: 15882.5
# Row 11469 Mean Squared Distance: 15882.5
# Row 11470 Mean Squared Distance: 15882.5
# Row 11471 Mean Squared Distance: 15882.5
# Row 11472 Mean Squared Distance: 15705.0
# Row 11473 Mean Squared Distance: 15528.5
# Row 11474 Mean Squared Distance: 15353.0
# Row 11475 Mean Squared Distance: 15353.0
# Row 11476 Mean Squared Distance: 15353.0
# Row 11477 Mean Squared Distance: 15353.0
# Row 11478 Mean Squared Distance: 15353.0
# Row 11479 Mean Squared Distance: 15362.5
# Row 11480 Mean Squared Distance: 15373.0
# Row 11481 Mean Squared Distance: 15384.5
# Row 11482 Mean Squared Distance: 15397.0
# Row 11483 Mean Squared Distance: 15410.5
# Row 11484 Mean Squared Distance: 15425.0
# Row 11485 Mean Squared Distance: 15440.5
# Row 11486 Mean Squared Distance: 15440.5
# Row 11487 Mean Squared Distance: 15440.5
# Row 11488 Mean Squared Distance: 15266.0
# Row 11489 Mean Squared Distance: 15092.5
# Row 11490 Mean Squared Distance: 14920.0
# Row 11491 Mean Squared Distance: 14748.5
# Row 11492 Mean Squared Distance: 14578.0
# Row 11493 Mean Squared Distance: 14408.5
# Row 11494 Mean Squared Distance: 14408.5
# Row 11495 Mean Squared Distance: 14408.5
# Row 11496 Mean Squared Distance: 14408.5
# Row 11497 Mean Squared Distance: 14408.5
# Row 11498 Mean Squared Distance: 14408.5
# Row 11499 Mean Squared Distance: 14408.5
# Row 11500 Mean Squared Distance: 14408.5
# Row 11501 Mean Squared Distance: 14408.5
# Row 11502 Mean Squared Distance: 14408.5
# Row 11503 Mean Squared Distance: 14408.5
# Row 11504 Mean Squared Distance: 14408.5
# Row 11505 Mean Squared Distance: 14408.5
# Row 11506 Mean Squared Distance: 14408.5
# Row 11507 Mean Squared Distance: 14408.5
# Row 11508 Mean Squared Distance: 14408.5
# Row 11509 Mean Squared Distance: 14408.5
# Row 11510 Mean Squared Distance: 14408.5
# Row 11511 Mean Squared Distance: 14408.5
# Row 11512 Mean Squared Distance: 14408.5
# Row 11513 Mean Squared Distance: 14408.5
# Row 11514 Mean Squared Distance: 14408.5
# Row 11515 Mean Squared Distance: 14408.5
# Row 11516 Mean Squared Distance: 14408.5
# Row 11517 Mean Squared Distance: 14408.5
# Row 11518 Mean Squared Distance: 14240.0
# Row 11519 Mean Squared Distance: 14072.5
# Row 11520 Mean Squared Distance: 13906.0
# Row 11521 Mean Squared Distance: 13740.5
# Row 11522 Mean Squared Distance: 13576.0
# Row 11523 Mean Squared Distance: 13412.5
# Row 11524 Mean Squared Distance: 13250.0
# Row 11525 Mean Squared Distance: 13088.5
# Row 11526 Mean Squared Distance: 12928.0
# Row 11527 Mean Squared Distance: 12768.5
# Row 11528 Mean Squared Distance: 12610.0
# Row 11529 Mean Squared Distance: 12452.5
# Row 11530 Mean Squared Distance: 12296.0
# Row 11531 Mean Squared Distance: 12140.5
# Row 11532 Mean Squared Distance: 11986.0
# Row 11533 Mean Squared Distance: 11832.5
# Row 11534 Mean Squared Distance: 11832.5
# Row 11535 Mean Squared Distance: 11832.5
# Row 11536 Mean Squared Distance: 11832.5
# Row 11537 Mean Squared Distance: 11832.5
# Row 11538 Mean Squared Distance: 11832.5
# Row 11539 Mean Squared Distance: 11832.5
# Row 11540 Mean Squared Distance: 11832.5
# Row 11541 Mean Squared Distance: 11832.5
# Row 11542 Mean Squared Distance: 11680.0
# Row 11543 Mean Squared Distance: 11528.5
# Row 11544 Mean Squared Distance: 11545.0
# Row 11545 Mean Squared Distance: 11562.5
# Row 11546 Mean Squared Distance: 11581.0
# Row 11547 Mean Squared Distance: 11430.5
# Row 11548 Mean Squared Distance: 11281.0
# Row 11549 Mean Squared Distance: 11300.5
# Row 11550 Mean Squared Distance: 11300.5
# Row 11551 Mean Squared Distance: 11300.5
# Row 11552 Mean Squared Distance: 11300.5
# Row 11553 Mean Squared Distance: 11300.5
# Row 11554 Mean Squared Distance: 11300.5
# Row 11555 Mean Squared Distance: 11300.5
# Row 11556 Mean Squared Distance: 11300.5
# Row 11557 Mean Squared Distance: 11300.5
# Row 11558 Mean Squared Distance: 11300.5
# Row 11559 Mean Squared Distance: 11300.5
# Row 11560 Mean Squared Distance: 11300.5
# Row 11561 Mean Squared Distance: 11300.5
# Row 11562 Mean Squared Distance: 11152.0
# Row 11563 Mean Squared Distance: 11004.5
# Row 11564 Mean Squared Distance: 10858.0
# Row 11565 Mean Squared Distance: 10712.5
# Row 11566 Mean Squared Distance: 10568.0
# Row 11567 Mean Squared Distance: 10424.5
# Row 11568 Mean Squared Distance: 10282.0
# Row 11569 Mean Squared Distance: 10140.5
# Row 11570 Mean Squared Distance: 10000.0
# Row 11571 Mean Squared Distance: 10000.0
# Row 11572 Mean Squared Distance: 10000.0
# Row 11573 Mean Squared Distance: 10000.0
# Row 11574 Mean Squared Distance: 10000.0
# Row 11575 Mean Squared Distance: 10000.0
# Row 11576 Mean Squared Distance: 10000.0
# Row 11577 Mean Squared Distance: 10000.0
# Row 11578 Mean Squared Distance: 10000.0
# Row 11579 Mean Squared Distance: 10000.0
# Row 11580 Mean Squared Distance: 10000.0
# Row 11581 Mean Squared Distance: 10000.0
# Row 11582 Mean Squared Distance: 10000.0
# Row 11583 Mean Squared Distance: 10000.0
# Row 11584 Mean Squared Distance: 10000.0
# Row 11585 Mean Squared Distance: 9860.5
# Row 11586 Mean Squared Distance: 9722.0
# Row 11587 Mean Squared Distance: 9584.5
# Row 11588 Mean Squared Distance: 9448.0
# Row 11589 Mean Squared Distance: 9312.5
# Row 11590 Mean Squared Distance: 9178.0
# Row 11591 Mean Squared Distance: 9044.5
# Row 11592 Mean Squared Distance: 8912.0
# Row 11593 Mean Squared Distance: 8780.5
# Row 11594 Mean Squared Distance: 8650.0
# Row 11595 Mean Squared Distance: 8520.5
# Row 11596 Mean Squared Distance: 8392.0
# Row 11597 Mean Squared Distance: 8264.5
# Row 11598 Mean Squared Distance: 8138.0
# Row 11599 Mean Squared Distance: 8012.5
# Row 11600 Mean Squared Distance: 7888.0
# Row 11601 Mean Squared Distance: 7764.5
# Row 11602 Mean Squared Distance: 7642.0
# Row 11603 Mean Squared Distance: 7520.5
# Row 11604 Mean Squared Distance: 7400.0
# Row 11605 Mean Squared Distance: 7280.5
# Row 11606 Mean Squared Distance: 7162.0
# Row 11607 Mean Squared Distance: 7044.5
# Row 11608 Mean Squared Distance: 6928.0
# Row 11609 Mean Squared Distance: 6812.5
# Row 11610 Mean Squared Distance: 6698.0
# Row 11611 Mean Squared Distance: 6584.5
# Row 11612 Mean Squared Distance: 6472.0
# Row 11613 Mean Squared Distance: 6360.5
# Row 11614 Mean Squared Distance: 6250.0
# Row 11615 Mean Squared Distance: 6140.5
# Row 11616 Mean Squared Distance: 6032.0
# Row 11617 Mean Squared Distance: 5924.5
# Row 11618 Mean Squared Distance: 5818.0
# Row 11619 Mean Squared Distance: 5712.5
# Row 11620 Mean Squared Distance: 5608.0
# Row 11621 Mean Squared Distance: 5504.5
# Row 11622 Mean Squared Distance: 5402.0
# Row 11623 Mean Squared Distance: 5300.5
# Row 11624 Mean Squared Distance: 5200.0
# Row 11625 Mean Squared Distance: 5100.5
# Row 11626 Mean Squared Distance: 5002.0
# Row 11627 Mean Squared Distance: 4904.5
# Row 11628 Mean Squared Distance: 4808.0
# Row 11629 Mean Squared Distance: 4712.5
# Row 11630 Mean Squared Distance: 4618.0
# Row 11631 Mean Squared Distance: 4524.5
# Row 11632 Mean Squared Distance: 4432.0
# Row 11633 Mean Squared Distance: 4340.5
# Row 11634 Mean Squared Distance: 4250.0
# Row 11635 Mean Squared Distance: 4160.5
# Row 11636 Mean Squared Distance: 4072.0
# Row 11637 Mean Squared Distance: 3984.5
# Row 11638 Mean Squared Distance: 3898.0
# Row 11639 Mean Squared Distance: 3812.5
# Row 11640 Mean Squared Distance: 3728.0
# Row 11641 Mean Squared Distance: 3644.5
# Row 11642 Mean Squared Distance: 3562.0
# Row 11643 Mean Squared Distance: 3480.5
# Row 11644 Mean Squared Distance: 3400.0
# Row 11645 Mean Squared Distance: 3400.0
# Row 11646 Mean Squared Distance: 3400.0
# Row 11647 Mean Squared Distance: 3400.0
# Row 11648 Mean Squared Distance: 3400.0
# Row 11649 Mean Squared Distance: 3400.0
# Row 11650 Mean Squared Distance: 3420.5
# Row 11651 Mean Squared Distance: 3442.0
# Row 11652 Mean Squared Distance: 3464.5
# Row 11653 Mean Squared Distance: 3488.0
# Row 11654 Mean Squared Distance: 3512.5
# Row 11655 Mean Squared Distance: 3538.0
# Row 11656 Mean Squared Distance: 3564.5
# Row 11657 Mean Squared Distance: 3564.5
# Row 11658 Mean Squared Distance: 3564.5
# Row 11659 Mean Squared Distance: 3485.0
# Row 11660 Mean Squared Distance: 3406.5
# Row 11661 Mean Squared Distance: 3329.0
# Row 11662 Mean Squared Distance: 3252.5
# Row 11663 Mean Squared Distance: 3177.0
# Row 11664 Mean Squared Distance: 3102.5
# Row 11665 Mean Squared Distance: 3029.0
# Row 11666 Mean Squared Distance: 2956.5
# Row 11667 Mean Squared Distance: 2885.0
# Row 11668 Mean Squared Distance: 2814.5
# Row 11669 Mean Squared Distance: 2745.0
# Row 11670 Mean Squared Distance: 2745.0
# Row 11671 Mean Squared Distance: 2745.0
# Row 11672 Mean Squared Distance: 2745.0
# Row 11673 Mean Squared Distance: 2745.0
# Row 11674 Mean Squared Distance: 2745.0
# Row 11675 Mean Squared Distance: 2745.0
# Row 11676 Mean Squared Distance: 2745.0
# Row 11677 Mean Squared Distance: 2745.0
# Row 11678 Mean Squared Distance: 2745.0
# Row 11679 Mean Squared Distance: 2745.0
# Row 11680 Mean Squared Distance: 2745.0
# Row 11681 Mean Squared Distance: 2745.0
# Row 11682 Mean Squared Distance: 2745.0
# Row 11683 Mean Squared Distance: 2745.0
# Row 11684 Mean Squared Distance: 2745.0
# Row 11685 Mean Squared Distance: 2745.0
# Row 11686 Mean Squared Distance: 2745.0
# Row 11687 Mean Squared Distance: 2745.0
# Row 11688 Mean Squared Distance: 2745.0
# Row 11689 Mean Squared Distance: 2745.0
# Row 11690 Mean Squared Distance: 2745.0
# Row 11691 Mean Squared Distance: 2745.0
# Row 11692 Mean Squared Distance: 2745.0
# Row 11693 Mean Squared Distance: 2745.0
# Row 11694 Mean Squared Distance: 2745.0
# Row 11695 Mean Squared Distance: 2745.0
# Row 11696 Mean Squared Distance: 2745.0
# Row 11697 Mean Squared Distance: 2745.0
# Row 11698 Mean Squared Distance: 2745.0
# Row 11699 Mean Squared Distance: 2718.5
# Row 11700 Mean Squared Distance: 2693.0
# Row 11701 Mean Squared Distance: 2668.5
# Row 11702 Mean Squared Distance: 2645.0
# Row 11703 Mean Squared Distance: 2622.5
# Row 11704 Mean Squared Distance: 2601.0
# Row 11705 Mean Squared Distance: 2580.5
# Row 11706 Mean Squared Distance: 2561.0
# Row 11707 Mean Squared Distance: 2542.5
# Row 11708 Mean Squared Distance: 2525.0
# Row 11709 Mean Squared Distance: 2508.5
# Row 11710 Mean Squared Distance: 2493.0
# Row 11711 Mean Squared Distance: 2478.5
# Row 11712 Mean Squared Distance: 2465.0
# Row 11713 Mean Squared Distance: 2452.5
# Row 11714 Mean Squared Distance: 2441.0
# Row 11715 Mean Squared Distance: 2430.5
# Row 11716 Mean Squared Distance: 2421.0
# Row 11717 Mean Squared Distance: 2412.5
# Row 11718 Mean Squared Distance: 2405.0
# Row 11719 Mean Squared Distance: 2398.5
# Row 11720 Mean Squared Distance: 2393.0
# Row 11721 Mean Squared Distance: 2324.5
# Row 11722 Mean Squared Distance: 2257.0
# Row 11723 Mean Squared Distance: 2190.5
# Row 11724 Mean Squared Distance: 2125.0
# Row 11725 Mean Squared Distance: 2060.5
# Row 11726 Mean Squared Distance: 1997.0
# Row 11727 Mean Squared Distance: 1934.5
# Row 11728 Mean Squared Distance: 1873.0
# Row 11729 Mean Squared Distance: 1812.5
# Row 11730 Mean Squared Distance: 1753.0
# Row 11731 Mean Squared Distance: 1694.5
# Row 11732 Mean Squared Distance: 1637.0
# Row 11733 Mean Squared Distance: 1580.5
# Row 11734 Mean Squared Distance: 1525.0
# Row 11735 Mean Squared Distance: 1470.5
# Row 11736 Mean Squared Distance: 1417.0
# Row 11737 Mean Squared Distance: 1364.5
# Row 11738 Mean Squared Distance: 1313.0
# Row 11739 Mean Squared Distance: 1262.5
# Row 11740 Mean Squared Distance: 1213.0
# Row 11741 Mean Squared Distance: 1164.5
# Row 11742 Mean Squared Distance: 1117.0
# Row 11743 Mean Squared Distance: 1070.5
# Row 11744 Mean Squared Distance: 1070.5
# Row 11745 Mean Squared Distance: 1070.5
# Row 11746 Mean Squared Distance: 1070.5
# Row 11747 Mean Squared Distance: 1070.5
# Row 11748 Mean Squared Distance: 1070.5
# Row 11749 Mean Squared Distance: 1070.5
# Row 11750 Mean Squared Distance: 1070.5
# Row 11751 Mean Squared Distance: 1070.5
# Row 11752 Mean Squared Distance: 1070.5
# Row 11753 Mean Squared Distance: 1070.5
# Row 11754 Mean Squared Distance: 1070.5
# Row 11755 Mean Squared Distance: 1070.5
# Row 11756 Mean Squared Distance: 1070.5
# Row 11757 Mean Squared Distance: 1070.5
# Row 11758 Mean Squared Distance: 1025.0
# Row 11759 Mean Squared Distance: 980.5
# Row 11760 Mean Squared Distance: 937.0
# Row 11761 Mean Squared Distance: 894.5
# Row 11762 Mean Squared Distance: 853.0
# Row 11763 Mean Squared Distance: 812.5
# Row 11764 Mean Squared Distance: 773.0
# Row 11765 Mean Squared Distance: 734.5
# Row 11766 Mean Squared Distance: 697.0
# Row 11767 Mean Squared Distance: 660.5
# Row 11768 Mean Squared Distance: 625.0
# Row 11769 Mean Squared Distance: 590.5
# Row 11770 Mean Squared Distance: 557.0
# Row 11771 Mean Squared Distance: 524.5
# Row 11772 Mean Squared Distance: 493.0
# Row 11773 Mean Squared Distance: 462.5
# Row 11774 Mean Squared Distance: 433.0
# Row 11775 Mean Squared Distance: 404.5
# Row 11776 Mean Squared Distance: 377.0
# Row 11777 Mean Squared Distance: 350.5
# Row 11778 Mean Squared Distance: 325.0
# Row 11779 Mean Squared Distance: 300.5
# Row 11780 Mean Squared Distance: 277.0
# Row 11781 Mean Squared Distance: 254.5
# Row 11782 Mean Squared Distance: 233.0
# Row 11783 Mean Squared Distance: 212.5
# Row 11784 Mean Squared Distance: 193.0
# Row 11785 Mean Squared Distance: 174.5
# Row 11786 Mean Squared Distance: 157.0
# Row 11787 Mean Squared Distance: 140.5
# Row 11788 Mean Squared Distance: 125.0
# Row 11789 Mean Squared Distance: 110.5
# Row 11790 Mean Squared Distance: 97.0
# Row 11791 Mean Squared Distance: 84.5
# Row 11792 Mean Squared Distance: 73.0
# Row 11793 Mean Squared Distance: 62.5
# Row 11794 Mean Squared Distance: 53.0
# Row 11795 Mean Squared Distance: 44.5
# Row 11796 Mean Squared Distance: 37.0
# Row 11797 Mean Squared Distance: 30.5
# Row 11798 Mean Squared Distance: 25.0
# Row 11799 Mean Squared Distance: 20.5
# Row 11800 Mean Squared Distance: 17.0
# Row 11801 Mean Squared Distance: 14.5
# Row 11802 Mean Squared Distance: 13.0
# Row 11803 Mean Squared Distance: 12.5
# Row 11804 Mean Squared Distance: 13.0
# Row 11805 Mean Squared Distance: 14.5
# Row 11806 Mean Squared Distance: 17.0
# Row 11807 Mean Squared Distance: 20.5
# Row 11808 Mean Squared Distance: 25.0
# Row 11809 Mean Squared Distance: 30.5
# Row 11810 Mean Squared Distance: 37.0
# Row 11811 Mean Squared Distance: 44.5
# Row 11812 Mean Squared Distance: 53.0
# Row 11813 Mean Squared Distance: 62.5
# Row 11814 Mean Squared Distance: 73.0
# Row 11815 Mean Squared Distance: 84.5
# Row 11816 Mean Squared Distance: 97.0
# Row 11817 Mean Squared Distance: 110.5
# Row 11818 Mean Squared Distance: 125.0
# Row 11819 Mean Squared Distance: 140.5
# Row 11820 Mean Squared Distance: 157.0
# Row 11821 Mean Squared Distance: 174.5
# Row 11822 Mean Squared Distance: 193.0
# Row 11823 Mean Squared Distance: 212.5
# Row 11824 Mean Squared Distance: 233.0
# Row 11825 Mean Squared Distance: 254.5
# Row 11826 Mean Squared Distance: 277.0
# Row 11827 Mean Squared Distance: 300.5
# Row 11828 Mean Squared Distance: 325.0
# Row 11829 Mean Squared Distance: 350.5
# Row 11830 Mean Squared Distance: 377.0
# Row 11831 Mean Squared Distance: 404.5
# Row 11832 Mean Squared Distance: 433.0
# Row 11833 Mean Squared Distance: 462.5
# Row 11834 Mean Squared Distance: 493.0
# Index(['beam_000_dist_to_obj0', 'beam_000_dist_to_obj1',
#        'beam_000_dist_to_obj2', 'beam_001_dist_to_obj0',
#        'beam_001_dist_to_obj1', 'beam_001_dist_to_obj2',
#        'beam_002_dist_to_obj0', 'beam_002_dist_to_obj1',
#        'beam_002_dist_to_obj2', 'beam_003_dist_to_obj0',
#        ...
#        'beam_358_dist_to_obj0', 'beam_358_dist_to_obj1',
#        'beam_358_dist_to_obj2', 'beam_359_dist_to_obj0',
#        'beam_359_dist_to_obj1', 'beam_359_dist_to_obj2', 'P1_goal_dist_x',
#        'P1_goal_dist_y', 'final_row_flag', 'P1_action'],
#       dtype='object', length=1084)

# %%
final_state_flag_counts = df_filtered['final_row_flag'].value_counts()
print(final_state_flag_counts)
# Out:
# 0.0    1514
# 1.0       4
# Name: final_row_flag, dtype: int64

# %%
# Using .shape to get the number of rows and columns
num_rows, num_columns = df_filtered.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)

# Using len() to get the number of rows directly
num_rows = len(df_filtered)
print("Number of rows:", num_rows)
# Out:
# Number of rows: 1518
# Number of columns: 1084
# Number of rows: 1518

# %%
# Assuming P1_Direction is the target and all other columns are features
X = df_filtered.drop(['P1_action'], axis=1)
y = df_filtered['P1_action']

# %% [markdown]
# ##split into train test val
#
#  60% train, 20% validation, and 20% test split

# %%
from sklearn.model_selection import train_test_split

X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

# %% [markdown]
# ##convert df to numpy array then tensor

# %%
import torch
X_train_tensor = torch.tensor(X_train.to_numpy(), dtype=torch.float32)
X_val_tensor = torch.tensor(X_val.to_numpy(), dtype=torch.float32)
X_test_tensor = torch.tensor(X_test.to_numpy(), dtype=torch.float32)

y_train_tensor = torch.tensor(y_train.to_numpy(), dtype=torch.long)
y_val_tensor = torch.tensor(y_val.to_numpy(), dtype=torch.long)
y_test_tensor = torch.tensor(y_test.to_numpy(), dtype=torch.long)

# %% [markdown]
# ##Create Data Loader

# %%
# Create TensorDatasets
from torch.utils.data import TensorDataset, DataLoader
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

# Create DataLoaders
batch_size = 64  # You can adjust the batch size

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ##create model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset


import torch.nn as nn
import torch.nn.functional as F

class BCAgent(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(BCAgent, self).__init__()
        # Use the input_dim and output_dim arguments to adjust layer dimensions
        self.fc1 = nn.Linear(input_dim, 1024)
        self.bn1 = nn.BatchNorm1d(1024)
        self.dp1 = nn.Dropout(0.2)

        self.fc2 = nn.Linear(1024, 512)
        self.bn2 = nn.BatchNorm1d(512)
        self.dp2 = nn.Dropout(0.2)

        self.fc3 = nn.Linear(512, 128)
        self.bn3 = nn.BatchNorm1d(128)
        self.dp3 = nn.Dropout(0.2)

        self.fc4 = nn.Linear(128, 64)
        self.bn4 = nn.BatchNorm1d(64)
        self.dp4 = nn.Dropout(0.2)

        self.fc5 = nn.Linear(64, 32)
        self.bn5 = nn.BatchNorm1d(32)
        self.dp5 = nn.Dropout(0.2)

        self.fc6 = nn.Linear(32, output_dim)  # Use output_dim for the output layer

    def forward(self, x):
        x = F.relu(self.dp1(self.bn1(self.fc1(x))))
        x = F.relu(self.dp2(self.bn2(self.fc2(x))))
        x = F.relu(self.dp3(self.bn3(self.fc3(x))))
        x = F.relu(self.dp4(self.bn4(self.fc4(x))))
        x = F.relu(self.dp5(self.bn5(self.fc5(x))))
        x = self.fc6(x)
        return x

# %%
''''
**OLD**

model = Sequential([
    Dense(1024, activation='relu', input_shape=(26,), ),
    Dense(512, activation='relu', ),
    Dense(128, activation='relu', ),
    Dense(64, activation='relu', ),
    Dense(32, activation='relu', ),
    # Update the Dense layer for output according to your classification/regression needs
    Dense(5, activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
'''

# %%
'''
model = Sequential([
    Dense(512, activation='relu', input_shape=(26,), ),

    Dense(128, activation='relu', ),

    Dense(32, activation='relu', ),
    # Update the Dense layer for output according to your classification/regression needs
    Dense(5, activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
##RUN ON WAND B NAME-SOFT MEDOW
'''

# %%
''''
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

# Assuming X_train.shape[1] is 126, replace it with 126 directly if you're not sure
model = Sequential([
    Dense(1024, activation='relu', input_shape=(26,), ),
    Dense(512, activation='relu', ),
    Dense(256, activation='relu', ),
    Dense(128, activation='relu', ),
    Dense(64, activation='relu', ),
    Dense(32, activation='relu', ),
    # Update the Dense layer for output according to your classification/regression needs
    Dense(5, activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
###increasing depth deterioraes performance

##RUN ON WAND B NAME-GIDDY BUTTERFLY

''''

# %% [markdown]
# ##train

# %%
# !pip install wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.16.5-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.42-py3-none-any.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.44.0-py2.py3-none-any.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.9/264.9 kB 12.9 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.1)
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2024.2.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.42 docker-pycreds-0.4.0 gitdb-4.0.11 sentry-sdk-1.44.0 setproctitle-1.3.3 smmap-5.0.1 wandb-0.16.5

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping

# %%
import wandb
from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint, WandbEvalCallback


wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
import wandb
import numpy as np
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim
import torch

# EarlyStopping class to stop the training when a monitored metric has stopped improving.
class EarlyStopping:
    def __init__(self, patience=7, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = np.Inf
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss - val_loss > self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                print('Early stopping')
                self.early_stop = True

# %%
# Initialize WandB
wandb.init(project='GRProject Pytorch-LIDAR-CHANGEREP3', config={
    "learning_rate": 0.001,
    "epochs": 20,
    "batch_size": 64,
})
config = wandb.config
input_dim = X.shape[1]  # Number of columns in the DataFrame

model = BCAgent(input_dim=input_dim, output_dim=5)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=config.learning_rate)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

early_stopping = EarlyStopping(patience=10, min_delta=0.001)

for epoch in range(config.epochs):
    model.train()
    running_loss = 0.0
    correct_predictions = 0
    total_predictions = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)

        _, predicted = torch.max(outputs.data, 1)
        total_predictions += labels.size(0)
        correct_predictions += (predicted == labels).sum().item()

    epoch_loss = running_loss / total_predictions
    epoch_accuracy = (correct_predictions / total_predictions) * 100

    wandb.log({"Train_loss": epoch_loss, "Train_accuracy": epoch_accuracy})

    # Validation phase
    model.eval()  # Set the model to evaluation mode
    val_loss = 0.0
    correct_val_predictions = 0
    total_val_predictions = 0

    with torch.no_grad():  # No need to track gradients during validation
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item() * inputs.size(0)  # Accumulate the batch loss

            _, predicted = torch.max(outputs, 1)  # Get the index of the max log-probability
            total_val_predictions += labels.size(0)
            correct_val_predictions += (predicted == labels).sum().item()

    val_loss /= len(val_loader.dataset)
    val_accuracy = (correct_val_predictions / total_val_predictions) * 100

    # Log validation loss and accuracy to WandB
    wandb.log({"val_loss": val_loss, "val_accuracy": val_accuracy})
    # Call early stopping
    #early_stopping(_loss)
    #if early_stopping.early_stop:
        #print("Stopped early at epoch", epoch+1)
        #break
wandb.finish()
# Out:
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>/content/wandb/run-20240329_140236-qa1nmtcu</code>
# Syncing run <strong><a href='https://wandb.ai/hb12/GRProject%20Pytorch-LIDAR-CHANGEREP3/runs/qa1nmtcu/workspace' target="_blank">golden-blaze-2</a></strong> to <a href='https://wandb.ai/hb12/GRProject%20Pytorch-LIDAR-CHANGEREP3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hb12/GRProject%20Pytorch-LIDAR-CHANGEREP3' target="_blank">https://wandb.ai/hb12/GRProject%20Pytorch-LIDAR-CHANGEREP3</a>
#  View run at <a href='https://wandb.ai/hb12/GRProject%20Pytorch-LIDAR-CHANGEREP3/runs/qa1nmtcu/workspace' target="_blank">https://wandb.ai/hb12/GRProject%20Pytorch-LIDAR-CHANGEREP3/runs/qa1nmtcu/workspace</a>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_accuracy</td><td>▁▅▅▆▆▇▇▇▇▇▇█████████</td></tr><tr><td>Train_loss</td><td>█▆▅▄▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▂▂▄▅▅▅▅█▇▇▇▇▅▇▆██▆█</td></tr><tr><td>val_loss</td><td>█▅▄▄▄▃▂▃▂▂▂▂▂▃▁▂▁▁▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_accuracy</td><td>91.50391</td></tr><tr><td>Train_loss</td><td>0.2501</td></tr><tr><td>val_accuracy</td><td>88.0117</td></tr><tr><td>val_loss</td><td>0.32827</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">golden-blaze-2</strong> at: <a href='https://wandb.ai/hb12/GRProject%20Pytorch-LIDAR-CHANGEREP3/runs/qa1nmtcu/workspace' target="_blank">https://wandb.ai/hb12/GRProject%20Pytorch-LIDAR-CHANGEREP3/runs/qa1nmtcu/workspace</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240329_140236-qa1nmtcu/logs</code>

# %% [markdown]
# ##Inference

# %%
model_save_path = "/content/drive/MyDrive/GuidingRobot/model_checkpoints_relative/model_checkpoint_LIDAR_succesfultrials_1.pth"  # Define your save path here
wandb.init()
torch.save(model.state_dict(), model_save_path)
wandb.save(model_save_path)  # Optionally log the model file to WandB

wandb.finish()
# Out:
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>/content/wandb/run-20240329_140253-iqb78won</code>
# Syncing run <strong><a href='https://wandb.ai/hb12/uncategorized/runs/iqb78won/workspace' target="_blank">pious-butterfly-19</a></strong> to <a href='https://wandb.ai/hb12/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hb12/uncategorized' target="_blank">https://wandb.ai/hb12/uncategorized</a>
#  View run at <a href='https://wandb.ai/hb12/uncategorized/runs/iqb78won/workspace' target="_blank">https://wandb.ai/hb12/uncategorized/runs/iqb78won/workspace</a>
# VBox(children=(Label(value='6.576 MB of 6.576 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">pious-butterfly-19</strong> at: <a href='https://wandb.ai/hb12/uncategorized/runs/iqb78won/workspace' target="_blank">https://wandb.ai/hb12/uncategorized/runs/iqb78won/workspace</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20240329_140253-iqb78won/logs</code>

# %%
model.eval()  # Set the model to evaluation mode
test_loss = 0.0
correct_predictions = 0
total_predictions = 0

with torch.no_grad():  # Inference mode, no need to compute gradients
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)

        loss = criterion(outputs, labels)
        test_loss += loss.item() * inputs.size(0)  # Accumulate the batch loss

        _, predicted = torch.max(outputs, 1)
        total_predictions += labels.size(0)
        correct_predictions += (predicted == labels).sum().item()

test_loss /= len(test_loader.dataset)
test_accuracy = (correct_predictions / total_predictions) * 100
print("test loss",test_loss)
print("test acc",test_accuracy)
# Out:
# test loss 0.3547324028454329
# test acc 88.1578947368421
